# %%
import json
import signal
import sys
import datetime
import math
import pandas as pd
import numpy as np
from collections import Counter
import tensorflow as tf
from confluent_kafka import Producer, Consumer, KafkaException, KafkaError

# %%
FEATURE_COLS = [
    "EAR",
    "MAR",
    "yawn_rate_per_min",
    "blink_rate_per_min",
    "avg_blink_dur_sec",
    "longest_eye_closure_sec",
]

# %%
kafka_conf = {
    "bootstrap.servers": "kafka.dongango.com:9094",
}

# %%
conf = {
        **kafka_conf,
        "group.id": "zolgima-test-consumer-group",
        "enable.auto.commit": False,  # 수동 커밋
        "auto.offset.reset": "earliest",  # 처음부터 읽고 싶을 때
        "session.timeout.ms": 45000,
      }

c = Consumer(conf)
md = c.list_topics(timeout=5.)

# %%
mp4_topics = []
for tname, tmeta in md.topics.items():
    if tname.endswith(".mp4"):
        mp4_topics.append(tname)
    print(tname, "partitions:", len(tmeta.partitions))
print("MP4 topics:", mp4_topics)
# Out:
# sess-wphp1s2v-metnfuq9 partitions: 1
# gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 partitions: 1
# sess-37p61fgw-mesoq67n partitions: 1
# gC_14_s5_2019-03-12T09-18-58-01-00_rgb_face-label.mp4 partitions: 1
# sess-rucqrv95-metgmqz9 partitions: 1
# sess-5t1toq4k-mes66sgo partitions: 1
# sess-4wnf2c2g-metmesyx partitions: 1
# drowsiness_detection partitions: 1
# sess-zrl0v70k-metn0gx0 partitions: 1
# gC_15_s5_2019-03-12T11-03-23-01-00_rgb_face-label.mp4 partitions: 1
# gC_11_s5_2019-03-12T09-08-15-01-00_rgb_face-label.mp4 partitions: 1
# test-topic partitions: 1
# zolgima-control partitions: 1
# sess-igjk67gw-mep4nsua partitions: 1
# sess-penuvo24-metgrljb partitions: 1
# zolgima-test partitions: 1
# dongan-test-topic partitions: 1
# __consumer_offsets partitions: 50
# gC_13_s5_2019-03-12T10-03-00-01-00_rgb_face-label.mp4 partitions: 1
# MP4 topics: ['gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4', 'gC_14_s5_2019-03-12T09-18-58-01-00_rgb_face-label.mp4', 'gC_15_s5_2019-03-12T11-03-23-01-00_rgb_face-label.mp4', 'gC_11_s5_2019-03-12T09-08-15-01-00_rgb_face-label.mp4', 'gC_13_s5_2019-03-12T10-03-00-01-00_rgb_face-label.mp4']

# %%
frames_data = []
running = True

def handle_sigint(signum, frame):
    global running
    running = False

conf = {
        **kafka_conf,
        "group.id": "zolgima-test-consumer-group",
        "enable.auto.commit": False,  # 수동 커밋
        "auto.offset.reset": "earliest",  # 처음부터 읽고 싶을 때
        "session.timeout.ms": 45000,
}

c = Consumer(conf)
c.subscribe([mp4_topics[0]])

signal.signal(signal.SIGINT, handle_sigint)
print(f"👂 Subscribed to {mp4_topics[0]}. Press Ctrl+C to stop.")

try:
       while running:
              msg = c.poll(1.0)  # 1초 대기
              if msg is None:
                     continue
              if msg.error():
                # 파티션 EOF 등 무해한 에러 처리
                if msg.error().code() == KafkaError._PARTITION_EOF:
                    continue
                raise KafkaException(msg.error())

            # 정상 메시지 처리
              try:
                     value = msg.value()
                     data = json.loads(value.decode("utf-8")) if value else None
                     key = msg.key().decode("utf-8") if msg.key() else None
                     print(f"[{msg.topic()} p{msg.partition()} @ {msg.offset()}] "
                     f"key={key} data={data}")
                     frames_data.append(data)
              except json.JSONDecodeError as e:
                     print(f"⚠ JSON decode error: {e}; raw={msg.value()!r}")
finally:
       print("🛑 Closing consumer...")
       c.close()
# Out:
# 👂 Subscribed to gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4. Press Ctrl+C to stop.
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 0] key=drowniness_indicator data={'frame': 1, 'time_sec': 0.033602150537634407, 'label_id': 0, 'label_name': 'eyes_state/open', 'EAR': 0.23353539258047856, 'MAR': 0.003968072015843257, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 0.0, 'avg_blink_dur_sec': nan, 'longest_eye_closure_sec': nan, 'drowsiness_level': 0, 'drowsiness_label': 'alert'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 1] key=drowniness_indicator data={'frame': 2, 'time_sec': 0.06720430107526881, 'label_id': 0, 'label_name': 'eyes_state/open', 'EAR': 0.22623145485555213, 'MAR': 0.002633834758710877, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 0.0, 'avg_blink_dur_sec': nan, 'longest_eye_closure_sec': nan, 'drowsiness_level': 0, 'drowsiness_label': 'alert'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 2] key=drowniness_indicator data={'frame': 3, 'time_sec': 0.10080645161290322, 'label_id': 3, 'label_name': 'eyes_state/closing', 'EAR': 0.22795191106620422, 'MAR': 0.0017878851955445993, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 0.0, 'avg_blink_dur_sec': nan, 'longest_eye_closure_sec': nan, 'drowsiness_level': 0, 'drowsiness_label': 'alert'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 3] key=drowniness_indicator data={'frame': 4, 'time_sec': 0.13440860215053763, 'label_id': 3, 'label_name': 'eyes_state/closing', 'EAR': 0.2242770259217195, 'MAR': 0.000838679262671707, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 0.0, 'avg_blink_dur_sec': nan, 'longest_eye_closure_sec': nan, 'drowsiness_level': 0, 'drowsiness_label': 'alert'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 4] key=drowniness_indicator data={'frame': 5, 'time_sec': 0.16801075268817203, 'label_id': 2, 'label_name': 'eyes_state/opening', 'EAR': 0.23822499904223404, 'MAR': 0.0016036494630442843, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 0.0, 'avg_blink_dur_sec': nan, 'longest_eye_closure_sec': nan, 'drowsiness_level': 0, 'drowsiness_label': 'alert'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 5] key=drowniness_indicator data={'frame': 6, 'time_sec': 0.20161290322580644, 'label_id': 2, 'label_name': 'eyes_state/opening', 'EAR': 0.2279784505364501, 'MAR': 0.002765366616818113, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 0.0, 'avg_blink_dur_sec': nan, 'longest_eye_closure_sec': nan, 'drowsiness_level': 0, 'drowsiness_label': 'alert'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 6] key=drowniness_indicator data={'frame': 7, 'time_sec': 0.23521505376344085, 'label_id': 3, 'label_name': 'eyes_state/closing', 'EAR': 0.23391949324697997, 'MAR': 0.0008615435283984706, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 0.0, 'avg_blink_dur_sec': nan, 'longest_eye_closure_sec': nan, 'drowsiness_level': 0, 'drowsiness_label': 'alert'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 7] key=drowniness_indicator data={'frame': 8, 'time_sec': 0.26881720430107525, 'label_id': 2, 'label_name': 'eyes_state/opening', 'EAR': 0.23740471334895275, 'MAR': 0.0015565028111498421, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 0.0, 'avg_blink_dur_sec': nan, 'longest_eye_closure_sec': nan, 'drowsiness_level': 0, 'drowsiness_label': 'alert'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 8] key=drowniness_indicator data={'frame': 9, 'time_sec': 0.3024193548387097, 'label_id': 2, 'label_name': 'eyes_state/opening', 'EAR': 0.2441823543733901, 'MAR': 0.0006785093044536566, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 0.0, 'avg_blink_dur_sec': nan, 'longest_eye_closure_sec': nan, 'drowsiness_level': 0, 'drowsiness_label': 'alert'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 9] key=drowniness_indicator data={'frame': 10, 'time_sec': 0.33602150537634407, 'label_id': 2, 'label_name': 'eyes_state/opening', 'EAR': 0.24837603986511855, 'MAR': 0.0012326460741707403, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 0.0, 'avg_blink_dur_sec': nan, 'longest_eye_closure_sec': nan, 'drowsiness_level': 0, 'drowsiness_label': 'alert'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 10] key=drowniness_indicator data={'frame': 11, 'time_sec': 0.3696236559139785, 'label_id': 3, 'label_name': 'eyes_state/closing', 'EAR': 0.24191177743465284, 'MAR': 0.000876205805442412, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 0.0, 'avg_blink_dur_sec': nan, 'longest_eye_closure_sec': nan, 'drowsiness_level': 0, 'drowsiness_label': 'alert'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 11] key=drowniness_indicator data={'frame': 12, 'time_sec': 0.4032258064516129, 'label_id': 3, 'label_name': 'eyes_state/closing', 'EAR': 0.24439327474681383, 'MAR': 0.0008433225109536599, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 0.0, 'avg_blink_dur_sec': nan, 'longest_eye_closure_sec': nan, 'drowsiness_level': 0, 'drowsiness_label': 'alert'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 12] key=drowniness_indicator data={'frame': 13, 'time_sec': 0.4368279569892473, 'label_id': 3, 'label_name': 'eyes_state/closing', 'EAR': 0.2363579907674919, 'MAR': 0.0014485546167377148, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 0.0, 'avg_blink_dur_sec': nan, 'longest_eye_closure_sec': nan, 'drowsiness_level': 0, 'drowsiness_label': 'alert'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 13] key=drowniness_indicator data={'frame': 14, 'time_sec': 0.4704301075268817, 'label_id': 3, 'label_name': 'eyes_state/closing', 'EAR': 0.24032258742969048, 'MAR': 0.0008696556166740358, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 0.0, 'avg_blink_dur_sec': nan, 'longest_eye_closure_sec': nan, 'drowsiness_level': 0, 'drowsiness_label': 'alert'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 14] key=drowniness_indicator data={'frame': 15, 'time_sec': 0.5040322580645161, 'label_id': 3, 'label_name': 'eyes_state/closing', 'EAR': 0.23627738265976317, 'MAR': 0.0007609056152705527, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 0.0, 'avg_blink_dur_sec': nan, 'longest_eye_closure_sec': nan, 'drowsiness_level': 0, 'drowsiness_label': 'alert'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 15] key=drowniness_indicator data={'frame': 16, 'time_sec': 0.5376344086021505, 'label_id': 3, 'label_name': 'eyes_state/closing', 'EAR': 0.2172977688305004, 'MAR': 0.00046628154474280824, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 0.0, 'avg_blink_dur_sec': nan, 'longest_eye_closure_sec': nan, 'drowsiness_level': 0, 'drowsiness_label': 'alert'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 16] key=drowniness_indicator data={'frame': 17, 'time_sec': 0.5712365591397849, 'label_id': 3, 'label_name': 'eyes_state/closing', 'EAR': 0.2268814068680164, 'MAR': 0.0017210573953716688, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 0.0, 'avg_blink_dur_sec': nan, 'longest_eye_closure_sec': nan, 'drowsiness_level': 0, 'drowsiness_label': 'alert'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 17] key=drowniness_indicator data={'frame': 18, 'time_sec': 0.6048387096774194, 'label_id': 2, 'label_name': 'eyes_state/opening', 'EAR': 0.2264971443105917, 'MAR': 0.001323115884154996, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 0.0, 'avg_blink_dur_sec': nan, 'longest_eye_closure_sec': nan, 'drowsiness_level': 0, 'drowsiness_label': 'alert'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 18] key=drowniness_indicator data={'frame': 19, 'time_sec': 0.6384408602150538, 'label_id': 2, 'label_name': 'eyes_state/opening', 'EAR': 0.23460707000780423, 'MAR': 0.0012543655778817662, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 0.0, 'avg_blink_dur_sec': nan, 'longest_eye_closure_sec': nan, 'drowsiness_level': 0, 'drowsiness_label': 'alert'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 19] key=drowniness_indicator data={'frame': 20, 'time_sec': 0.6720430107526881, 'label_id': 2, 'label_name': 'eyes_state/opening', 'EAR': 0.23405727890439076, 'MAR': 0.0012993899121816292, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 0.0, 'avg_blink_dur_sec': nan, 'longest_eye_closure_sec': nan, 'drowsiness_level': 0, 'drowsiness_label': 'alert'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @
 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 39.0, 'avg_blink_dur_sec': 0.7599255583126548, 'longest_eye_closure_sec': 4.737903225806463, 'drowsiness_level': 3, 'drowsiness_label': 'severe_drowsy'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 5496] key=drowniness_indicator data={'frame': 5497, 'time_sec': 184.71102150537632, 'label_id': 0, 'label_name': 'eyes_state/open', 'EAR': 0.3151066548959698, 'MAR': 0.0007435010730031409, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 39.0, 'avg_blink_dur_sec': 0.7599255583126548, 'longest_eye_closure_sec': 4.737903225806463, 'drowsiness_level': 3, 'drowsiness_label': 'severe_drowsy'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 5497] key=drowniness_indicator data={'frame': 5498, 'time_sec': 184.74462365591395, 'label_id': 0, 'label_name': 'eyes_state/open', 'EAR': 0.31507671811832577, 'MAR': 0.000997561559997242, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 39.0, 'avg_blink_dur_sec': 0.7599255583126548, 'longest_eye_closure_sec': 4.737903225806463, 'drowsiness_level': 3, 'drowsiness_label': 'severe_drowsy'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 5498] key=drowniness_indicator data={'frame': 5499, 'time_sec': 184.77822580645162, 'label_id': 0, 'label_name': 'eyes_state/open', 'EAR': 0.319990639698739, 'MAR': 0.0011941023982794663, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 39.0, 'avg_blink_dur_sec': 0.7599255583126548, 'longest_eye_closure_sec': 4.737903225806463, 'drowsiness_level': 3, 'drowsiness_label': 'severe_drowsy'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 5499] key=drowniness_indicator data={'frame': 5500, 'time_sec': 184.81182795698925, 'label_id': 0, 'label_name': 'eyes_state/open', 'EAR': 0.3206279082055167, 'MAR': 0.001020258918896293, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 39.0, 'avg_blink_dur_sec': 0.7599255583126548, 'longest_eye_closure_sec': 4.737903225806463, 'drowsiness_level': 3, 'drowsiness_label': 'severe_drowsy'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 5500] key=drowniness_indicator data={'frame': 5501, 'time_sec': 184.84543010752688, 'label_id': 0, 'label_name': 'eyes_state/open', 'EAR': 0.31618234466463835, 'MAR': 0.0006929762099665614, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 39.0, 'avg_blink_dur_sec': 0.7599255583126548, 'longest_eye_closure_sec': 4.737903225806463, 'drowsiness_level': 3, 'drowsiness_label': 'severe_drowsy'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 5501] key=drowniness_indicator data={'frame': 5502, 'time_sec': 184.8790322580645, 'label_id': 0, 'label_name': 'eyes_state/open', 'EAR': 0.31791097830627485, 'MAR': 0.0011372512448156148, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 39.0, 'avg_blink_dur_sec': 0.7599255583126548, 'longest_eye_closure_sec': 4.737903225806463, 'drowsiness_level': 3, 'drowsiness_label': 'severe_drowsy'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 5502] key=drowniness_indicator data={'frame': 5503, 'time_sec': 184.91263440860214, 'label_id': 0, 'label_name': 'eyes_state/open', 'EAR': 0.3106865661513664, 'MAR': 0.001322091321950012, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 39.0, 'avg_blink_dur_sec': 0.7599255583126548, 'longest_eye_closure_sec': 4.737903225806463, 'drowsiness_level': 3, 'drowsiness_label': 'severe_drowsy'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 5503] key=drowniness_indicator data={'frame': 5504, 'time_sec': 184.94623655913978, 'label_id': 0, 'label_name': 'eyes_state/open', 'EAR': 0.30709027381177134, 'MAR': 0.00101266268907099, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 39.0, 'avg_blink_dur_sec': 0.7599255583126548, 'longest_eye_closure_sec': 4.737903225806463, 'drowsiness_level': 3, 'drowsiness_label': 'severe_drowsy'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 5504] key=drowniness_indicator data={'frame': 5505, 'time_sec': 184.9798387096774, 'label_id': 0, 'label_name': 'eyes_state/open', 'EAR': 0.3125880114889523, 'MAR': 0.0014367556942546892, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 39.0, 'avg_blink_dur_sec': 0.7599255583126548, 'longest_eye_closure_sec': 4.737903225806463, 'drowsiness_level': 3, 'drowsiness_label': 'severe_drowsy'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 5505] key=drowniness_indicator data={'frame': 5506, 'time_sec': 185.01344086021504, 'label_id': 0, 'label_name': 'eyes_state/open', 'EAR': 0.31775709396522506, 'MAR': 0.001330186787904838, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 39.0, 'avg_blink_dur_sec': 0.7599255583126548, 'longest_eye_closure_sec': 4.737903225806463, 'drowsiness_level': 3, 'drowsiness_label': 'severe_drowsy'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 5506] key=drowniness_indicator data={'frame': 5507, 'time_sec': 185.04704301075267, 'label_id': 0, 'label_name': 'eyes_state/open', 'EAR': 0.3184921203015605, 'MAR': 0.000813980092995419, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 39.0, 'avg_blink_dur_sec': 0.7599255583126548, 'longest_eye_closure_sec': 4.737903225806463, 'drowsiness_level': 3, 'drowsiness_label': 'severe_drowsy'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 5507] key=drowniness_indicator data={'frame': 5508, 'time_sec': 185.0806451612903, 'label_id': 0, 'label_name': 'eyes_state/open', 'EAR': 0.32114197973577085, 'MAR': 0.0011443179148397258, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 39.0, 'avg_blink_dur_sec': 0.7599255583126548, 'longest_eye_closure_sec': 4.737903225806463, 'drowsiness_level': 3, 'drowsiness_label': 'severe_drowsy'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 5508] key=drowniness_indicator data={'frame': 5509, 'time_sec': 185.11424731182794, 'label_id': 0, 'label_name': 'eyes_state/open', 'EAR': 0.32137646863242186, 'MAR': 0.0010592027125413796, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 39.0, 'avg_blink_dur_sec': 0.7599255583126548, 'longest_eye_closure_sec': 4.737903225806463, 'drowsiness_level': 3, 'drowsiness_label': 'severe_drowsy'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 5509] key=drowniness_indicator data={'frame': 5510, 'time_sec': 185.14784946236557, 'label_id': 0, 'label_name': 'eyes_state/open', 'EAR': 0.3208920986435143, 'MAR': 0.0010270424016814684, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 39.0, 'avg_blink_dur_sec': 0.7599255583126548, 'longest_eye_closure_sec': 4.737903225806463, 'drowsiness_level': 3, 'drowsiness_label': 'severe_drowsy'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 5510] key=drowniness_indicator data={'frame': 5511, 'time_sec': 185.1814516129032, 'label_id': 0, 'label_name': 'eyes_state/open', 'EAR': 0.305158813417696, 'MAR': 0.0014354581852189388, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 39.0, 'avg_blink_dur_sec': 0.7599255583126548, 'longest_eye_closure_sec': 4.737903225806463, 'drowsiness_level': 3, 'drowsiness_label': 'severe_drowsy'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 5511] key=drowniness_indicator data={'frame': 5512, 'time_sec': 185.21505376344086, 'label_id': 0, 'label_name': 'eyes_state/open', 'EAR': 0.3169836845608577, 'MAR': 0.00221955757459308, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 39.0, 'avg_blink_dur_sec': 0.7599255583126548, 'longest_eye_closure_sec': 4.737903225806463, 'drowsiness_level': 3, 'drowsiness_label': 'severe_drowsy'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 5512] key=drowniness_indicator data={'frame': 5513, 'time_sec': 185.2486559139785, 'label_id': 0, 'label_name': 'eyes_state/open', 'EAR': 0.315562606629403, 'MAR': 0.001966759907314559, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 39.0, 'avg_blink_dur_sec': 0.7599255583126548, 'longest_eye_closure_sec': 4.737903225806463, 'drowsiness_level': 3, 'drowsiness_label': 'severe_drowsy'}
# [gC_12_s5_2019-03-14T09-56-52-01-00_rgb_face-label.mp4 p0 @ 5513] key=drowniness_indicator data={'frame': 5514, 'time_sec': 185.28225806451613, 'label_id': 0, 'label_name': 'eyes_state/open', 'EAR': 0.32215587057434436, 'MAR': 0.0022441274388855887, 'yawn_rate_per_min': 0.0, 'blink_rate_per_min': 39.0, 'avg_blink_dur_sec': 0.7599255583126548, 'longest_eye_closure_sec': 4.737903225806463, 'drowsiness_level': 3, 'drowsiness_label': 'severe_drowsy'}
# 🛑 Closing consumer...

# %%
frame_df = pd.DataFrame(frames_data)
fps = 1 / frame_df.iloc[0]['time_sec']
window_size = 10.      # 초 단위 윈도우
hop_size = 1.         # 초 단위 홉

frame_window_size = int(round(fps * window_size, -1)) # 프레임 단위 윈도우(10단위 반올림)
frame_window_size
# Out:
# 300

# %%
def make_segments(df, frame_col, label_col, time_col, insert_gaps=True):
    d = df.sort_values(by=frame_col).reset_index(drop=True).copy()
    d[frame_col] = d[frame_col].astype(int)
    d[time_col] = round(d[time_col].astype(float), 3)
    d[label_col] = d[label_col].astype(int)
    if d.empty: 
        return []

    segs = []
    start = int(d.loc[0, frame_col])
    start_time = float(d.loc[0, time_col])
    prev_frame = start
    prev_label = int(d.loc[0, label_col])

    for i in range(1, len(d)):
        f = int(d.loc[i, frame_col])
        t = float(d.loc[i, time_col])
        lab = int(d.loc[i, label_col])
        # 프레임 갭(누락 프레임) 처리
        if f != prev_frame + 1:
            segs.append({"start": start, "end": prev_frame + 1, "label": prev_label, "note": "프레임 누락"})
            if insert_gaps and f > prev_frame + 1:
                segs.append({"start": prev_frame + 1, "end": f, "label": -1, "note": "무시"})  # 전이/무시
            start, start_time, prev_frame, prev_label = f, t, f, lab
            continue
        # 라벨 변경 경계
        if lab != prev_label:
            segs.append({"start": start, "end": f, "label": prev_label, "note": f"시간 표현: {start_time} ~ {t}"})
            start, start_time, prev_label = f, t, lab
        prev_frame = f

    segs.append({"start": start, "end": prev_frame + 1, "label": prev_label, "note": f"시간 표현: {start_time} ~ {t}"})
    return segs

def convert_csv_to_segments_json(df, fps=30):
    df = df[["frame", "time_sec", "drowsiness_level", "drowsiness_label"]]

    segments = make_segments(df, "frame", "drowsiness_level", "time_sec", insert_gaps=True)
    num_frames = int(df["frame"].max()) + 1

    friendly = {0:"정상", 1:"의심", 2:"주의", 3:"위험", -1:"무시"}
    class_map = [{"id": int(i), "name": friendly.get(int(i))} for i in friendly]

    payload = {
        "segments": segments
    }
    return payload

# %%
def parse_label_json(json_segment):
    segs = []
    
    def norm_one(d):
        # 키 변형 수용
        if isinstance(d, dict):
            # 유형 1: 명시 키
            s = d.get("start_frame", d.get("frame_start", d.get("start")))
            e = d.get("end_frame", d.get("frame_end", d.get("end")))
            lvl = d.get("level", d.get("lvl", d.get("label", d.get("state"))))
            if s is not None and e is not None and lvl is not None:
                return int(s), int(e), int(lvl)
            # 유형 2: frames: [s, e]
            if "frames" in d and isinstance(d["frames"], (list, tuple)) and len(d["frames"]) >= 2:
                s, e = d["frames"][:2]
                lvl = int(d.get("level", d.get("label", -1)))
                return int(s), int(e), int(lvl)
        return None

    for item in json_segment["segments"]:
       r = norm_one(item)
       if r: segs.append(r)

    # 정렬 & 병합은 생략(중복은 뒤값 우선)
    segs.sort(key=lambda x: (x[0], x[1]))
    return segs

def build_frame_labels(max_frame: int, segments, default_level):
    """
    0..max_frame 범위에 대해 프레임별 level 배열 만들기.
    """
    labels = np.full((max_frame+1,), default_level, dtype=np.int32)
    for s, e, lvl in segments:
        s = max(0, s); e = min(max_frame, e)
        if e >= s:
            labels[s:e+1] = int(lvl)
    return labels

# %%
def make_windows_for_pair(df, json_segment, window_sec, hop_sec, fps=30):
    """
    하나의 (CSV, JSON) 쌍에서 (X, y) 윈도우 생성
    - X: (num_win, seq_len, num_feat)
    - y: (num_win,)  # 윈도우 대표 레벨 (다수결)
    """
    win = max(1, int(round(window_sec * fps)))
    hop = max(1, int(round(hop_sec * fps)))

    # 프레임별 라벨
    segs = parse_label_json(json_segment)
    max_frame = int(df["frame"].max())
    frame_labels = build_frame_labels(max_frame, segs, default_level=-1)

    # 특성 행렬
    feats = df[FEATURE_COLS].astype(float).copy()
    # NaN 보정(앞채움→뒤채움→0)
    feats = feats.ffill().bfill().fillna(0.0)
    feat_np = feats.to_numpy(dtype=np.float32)
    frames = df["frame"].to_numpy(dtype=np.int32)

    # 프레임 인덱스 → 라벨 매핑
    label_by_row = np.array([frame_labels[f] if f <= max_frame else -1 for f in frames], dtype=np.int32)

    X_list, y_list = [], []
    start = 0
    last_start = len(df) - win
    while start <= last_start:
        end = start + win
        seq = feat_np[start:end, :]  # (win, feat)
        seq_labels = label_by_row[start:end]  # (win,)

        # 윈도우 대표 라벨: 다수결(동점이면 마지막 프레임값)
        cnt = Counter(seq_labels.tolist())
        most = max(cnt.items(), key=lambda kv: (kv[1], kv[0]))[0]
        y = most

        X_list.append(seq)
        y_list.append(y)
        start += hop
    
    if last_start < 0:
        # 데이터가 윈도우 길이보다 짧은 경우
        seq = np.zeros((win, len(FEATURE_COLS)), dtype=np.float32)
        seq[:len(feat_np), :] = feat_np
        cnt = Counter(label_by_row.tolist())
        most = max(cnt.items(), key=lambda kv: (kv[1], kv[0]))[0]
        y = most
        X_list.append(seq)
        y_list.append(y)

    if not X_list:
        return np.empty((0, win, len(FEATURE_COLS)), dtype=np.float32), np.empty((0,), dtype=np.int32)

    X = np.stack(X_list, axis=0).astype(np.float32)
    y = np.array(y_list, dtype=np.int32)
    return X, y

# %%
def build_numpy_dataset(df, json_segment, window_sec=5.0, hop_sec=1.0, fps=30):
    Xs, ys = [], []
    Xi, yi = make_windows_for_pair(df, json_segment, window_sec, hop_sec, fps)
    if len(Xi) > 0:
       Xs.append(Xi); ys.append(yi)
    if not Xs:
        raise RuntimeError("윈도우가 생성되지 않았습니다. 입력 파일/라벨을 확인하세요.")

    max_len = max(X.shape[1] for X in Xs)
    Xs_padded = [
        np.pad(X, ((0,0),(0,max_len-X.shape[1]),(0,0)), mode="constant")
        if X.shape[1] < max_len else X
        for X in Xs
    ]
    
    X = np.concatenate(Xs_padded, axis=0)
    y = np.concatenate(ys, axis=0)
    return X, y

# %%
segments = []
for i in range(math.ceil(len(frame_df) / frame_window_size)):
       df = frame_df.iloc[i*frame_window_size:(i+1)*frame_window_size]
       segment = convert_csv_to_segments_json(df=df, fps=fps)
       segments.append((df, segment))

# %%
pair = make_windows_for_pair(frame_df.iloc[0*frame_window_size:(0+1)*frame_window_size], convert_csv_to_segments_json(frame_df.iloc[0*frame_window_size:(0+1)*frame_window_size], fps=fps), window_sec=5.0, hop_sec=1.0, fps=fps)

# %%
pair[0].shape, pair[1].shape
# Out:
# ((6, 149, 6), (6,))

# %%
segments[0][0].shape
# Out:
# (300, 12)

# %%
inputs, outputs = [], []
for i in range(len(segments)):
       X, y = build_numpy_dataset(segments[i][0], segments[i][1], window_sec=window_size, hop_sec=hop_size, fps=fps)
       inputs.append(X)
       outputs.append(y)

# %%
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

# %%
def fit_standardizer(X: np.ndarray):
    """
    채널별 표준화 스케일러(평균/표준편차) 반환.
    """
    # X shape: (N, T, C)
    mean = X.reshape(-1, X.shape[-1]).mean(axis=0)
    std = X.reshape(-1, X.shape[-1]).std(axis=0)
    std = np.where(std < 1e-8, 1.0, std)
    return mean.astype(np.float32), std.astype(np.float32)

def apply_standardizer(X: np.ndarray, mean: np.ndarray, std: np.ndarray):
    return (X - mean) / std

# %%
input_scaleds = []
for i in range(len(inputs)):
       mean, std = fit_standardizer(inputs[i])
       X_scaled = apply_standardizer(inputs[i], mean, std)
       input_scaleds.append(X_scaled)

# %%
def to_tf_dataset(X: np.ndarray, batch=64, shuffle=True):
    # y를 인덱스로 변환(-1..3 → 0..4)
    ds = tf.data.Dataset.from_tensor_slices(X)
    if shuffle:
        ds = ds.shuffle(min(len(X), 10000), seed=RANDOM_SEED)
    ds = ds.batch(batch).prefetch(tf.data.AUTOTUNE)
    return ds

# %%
tf_datasets = []
for i in range(len(input_scaleds)):
       ds = to_tf_dataset(input_scaleds[i], batch=64, shuffle=True)
       tf_datasets.append(ds)

# %%
loaded_model = tf.keras.models.load_model("best_lstm.keras")
loaded_model.predict(tf_datasets[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 2
#       1 loaded_model = tf.keras.models.load_model("best_lstm.keras")
# ----> 2 loaded_model.predict(tf_datasets[0])
#
# File c:\ProgramData\anaconda3\envs\tf_env\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\ProgramData\anaconda3\envs\tf_env\Lib\site-packages\keras\src\layers\input_spec.py:245, in assert_input_compatibility(input_spec, inputs, layer_name)
#     243 if spec_dim is not None and dim is not None:
#     244     if spec_dim != dim:
# --> 245         raise ValueError(
#     246             f'Input {input_index} of layer "{layer_name}" is '
#     247             "incompatible with the layer: "
#     248             f"expected shape={spec.shape}, "
#     249             f"found shape={shape}"
#     250         )
#
# ValueError: Input 0 of layer "functional" is incompatible with the layer: expected shape=(None, 300, 6), found shape=(1, 298, 6)

# %% [markdown]
# **↑** 25.08.27 model에 들어가야 되는 입력의 크기와 slicing을 진행해 만들어진 입력의 shape가 달라지는 문제 발생...
# -> slicing한 데이터들을 입력 데이터로 가공하는 과정에서 생긴 문제 같아 보이는데 정확한 원인을 조사중

# %% [markdown]
# # 코드 설명
# ## 1. kafka 서버에서 consumer를 통해 topic을 지정해서 해당 topic의 messege를 불러온다. (Messege는 frame 마다의 정보를 담아있는 json 포맷 데이터)
# ## 2. messege를 코드 내부에서 csv, json 변수화 시켜 모델 입력에 들어갈 변수로 가공한다.
# ## 3. 가공은 영상을 읽을 때 나눌 window 크기 단위를 고려해서 영상을 slicing한다.(ex. window_size를 10초라고 하면 영상 slicing은 300프레임 단위)
# ## 4. slicing된 영상들을 model에 입력으로 넣어 각 프레임 구간 별 예측값을 출력으로 내보낸다.
# ### 해당 코드의 동작을 실시간 영상에 맞춰 돌아갈 수 있게끔 수정하는 작업을 추가로 진행해야 됨(현재는 파일 베이스)
